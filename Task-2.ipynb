# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
 df=pd.read_csv('Titanic-Dataset.csv')
print("\n---Dataset Info---")
print(df.info())

print("\n---Statistical Summary---")
print(df.describe())

print("\n---Missing values---")
print(df.isnull().sum())
# Out:
# ---Dataset Info---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# ---Statistical Summary---
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['Age'].dropna(), kde=True)
plt.title('Age Distriution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['Fare'].dropna(), kde=True)
plt.title('Fare Distriution')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='Survived', y='Age', data=df)
plt.title('Boxplot: Age vs Survived')
plt.show()

plt.figure(figsize=(12,5))
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title('Boxplot: Fare vs Pclass')
plt.show()

# %%
df_corr = df.copy()
df_corr['Sex']=corr_df['Sex'].map({'male' : 0, 'female' : 1})
df_corr['Embarked']=corr_df['Embarked'].map({'S' : 0, 'C' : 1, 'Q' : 2})
df_corr.drop(columns=['Name', 'Ticket' , 'Cabin'], inplace=True, errors='ignore')

plt.figure(figsize=(10,8))
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Fixed code - added parentheses to call the dropna() method
sns.pairplot(corr_df[['Survived', 'Age', 'Fare', 'Pclass', 'Sex']].dropna(), hue='Survived')
plt.suptitle('Pairplot of Selected Features', y=1.02)
plt.show()
